# %%
t= (1,2,3)

l1= list(t)
l1[2]= 10
tup= tuple(l1)
print(tup)
# Out:
# (1, 2, 10)

# %%
t= (1,2,3,4)

print("sum: ", sum(t))
# Out:
# sum:  10

# %%
#error
var=3

result= tuple(var)

print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 var=3
# ----> 3 result= tuple(var)
#       5 print(result)
#
# TypeError: 'int' object is not iterable

# %%
t= (10, 20, 40)

t_updated= t[:1] + (99,) + t[2:]

print("updated tuple: ", t_updated)
# Out:
# updated tuple:  (10, 99, 40)

# %%
month= ["jan", "feb", "june"]
expense= [120, 240, 850]

total= list(zip(month, expense))
print("total expense each month:", total)
# Out:
# total expense each month: [('jan', 120), ('feb', 240), ('june', 850)]

# %%
total = [('jan', 120), ('feb', 240), ('june', 850)]
month, expense= zip(*total)

print(month)
print(expense)
# Out:
# ('jan', 'feb', 'june')
# (120, 240, 850)
